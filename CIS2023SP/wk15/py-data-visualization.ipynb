# %% [markdown]
# # Parker McQuade
# ## Week 15 - 04/25/2023
# ### Python Data Visualization - Making informative visualizations (using figures and plots)

# %%
# The normal imports
import numpy as np 
from numpy.random import randn, randint
import pandas as pd
from pandas import Series, DataFrame

# Plotting modules and libraries we will use 
import matplotlib as mpl
import matplotlib.pyplot as plt

#Command so that plots appeat in the iPython Notebook
# %matplotlib inline

# %%
ts = Series(randn(1000), index=pd.date_range("1/1/2023", periods=1000))
ts
# Out:
# 2023-01-01    0.918043
# 2023-01-02   -0.046792
# 2023-01-03   -1.336410
# 2023-01-04   -1.143983
# 2023-01-05   -1.328057
#                 ...
# 2025-09-22   -0.023690
# 2025-09-23   -0.179567
# 2025-09-24   -0.856657
# 2025-09-25   -1.092028
# 2025-09-26    1.495428
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2023-01-01    0.918043
# 2023-01-02    0.871250
# 2023-01-03   -0.465160
# 2023-01-04   -1.609144
# 2023-01-05   -2.937201
#                 ...
# 2025-09-22    3.332193
# 2025-09-23    3.152626
# 2025-09-24    2.295969
# 2025-09-25    1.203941
# 2025-09-26    2.699369
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
df = DataFrame(randn(1000,4), index=ts.index, columns=list('abcd'))
df.cumsum
df
# Out:
#                    a         b         c         d
# 2023-01-01  0.847898 -0.045518 -0.019359 -0.472542
# 2023-01-02 -0.188561 -0.606498 -1.308310  0.424387
# 2023-01-03  0.035003  0.328125 -0.597407  1.640597
# 2023-01-04  0.097233  1.124472 -0.661965 -1.146242
# 2023-01-05 -0.766310  0.837900  1.035727 -0.666394
# ...              ...       ...       ...       ...
# 2025-09-22  0.838570 -1.458584 -1.337358  1.359415
# 2025-09-23 -0.556782 -0.448176  1.039547  0.994300
# 2025-09-24  1.964727  0.135533 -1.171381 -1.748981
# 2025-09-25 -0.440510  0.905512 -0.488408 -0.447566
# 2025-09-26 -0.421390 -0.653029  0.138049  1.359930
#
# [1000 rows x 4 columns]

# %%
df.plot()

# %%
df = DataFrame(randn(1000,2), columns=['B','C']).cumsum()
df
# Out:
#              B          C
# 0     0.271070   2.238118
# 1     0.585838   2.335497
# 2    -0.728944   4.193009
# 3    -1.257527   6.128246
# 4    -0.349834   5.043339
# ..         ...        ...
# 995 -17.165291  26.037332
# 996 -15.810726  27.150594
# 997 -17.178314  27.941358
# 998 -17.190811  26.952340
# 999 -15.870221  26.361685
#
# [1000 rows x 2 columns]

# %%
df.plot()

# %%
df['A'] = Series(list(df.index))
df
# Out:
#              B          C    A
# 0     0.271070   2.238118    0
# 1     0.585838   2.335497    1
# 2    -0.728944   4.193009    2
# 3    -1.257527   6.128246    3
# 4    -0.349834   5.043339    4
# ..         ...        ...  ...
# 995 -17.165291  26.037332  995
# 996 -15.810726  27.150594  996
# 997 -17.178314  27.941358  997
# 998 -17.190811  26.952340  998
# 999 -15.870221  26.361685  999
#
# [1000 rows x 3 columns]

# %%
df.plot(x='A', y='B')

# %%
df.plot(x='A', y='C')

# %%
df
# Out:
#              B          C    A
# 0     0.271070   2.238118    0
# 1     0.585838   2.335497    1
# 2    -0.728944   4.193009    2
# 3    -1.257527   6.128246    3
# 4    -0.349834   5.043339    4
# ..         ...        ...  ...
# 995 -17.165291  26.037332  995
# 996 -15.810726  27.150594  996
# 997 -17.178314  27.941358  997
# 998 -17.190811  26.952340  998
# 999 -15.870221  26.361685  999
#
# [1000 rows x 3 columns]

# %%
df.drop('A', axis=1)
# Out:
#              B          C
# 0     0.271070   2.238118
# 1     0.585838   2.335497
# 2    -0.728944   4.193009
# 3    -1.257527   6.128246
# 4    -0.349834   5.043339
# ..         ...        ...
# 995 -17.165291  26.037332
# 996 -15.810726  27.150594
# 997 -17.178314  27.941358
# 998 -17.190811  26.952340
# 999 -15.870221  26.361685
#
# [1000 rows x 2 columns]

# %%
data = randn(50)
data
# Out:
# array([-0.10328974,  1.18874513, -0.63481332,  0.61070285,  0.73338336,
#        -1.37136798,  0.11289355,  0.42941526, -0.11915184,  0.65090256,
#         0.91692022,  1.26364585,  0.17887899,  1.04608895, -1.4098452 ,
#        -0.40551243,  1.53067789,  0.9975551 , -0.87140729,  0.65076181,
#         0.5314576 ,  0.07170849, -1.5106156 , -0.77841549, -1.0495533 ,
#        -0.74309071, -1.05158221,  0.281058  ,  0.21486062,  0.3917851 ,
#         1.52113114,  1.76047483,  0.10358265, -0.27341562, -0.83701533,
#         0.43207583, -0.17671246, -0.1951722 , -2.14307198, -0.0545428 ,
#         0.65781564,  0.53381235,  1.00782279, -0.91564401, -0.58014075,
#        -0.30526417, -1.08997381,  1.29334017,  0.01327209, -0.7640369 ])

# %%
s = Series(data)
s
# Out:
# 0    -0.103290
# 1     1.188745
# 2    -0.634813
# 3     0.610703
# 4     0.733383
# 5    -1.371368
# 6     0.112894
# 7     0.429415
# 8    -0.119152
# 9     0.650903
# 10    0.916920
# 11    1.263646
# 12    0.178879
# 13    1.046089
# 14   -1.409845
# 15   -0.405512
# 16    1.530678
# 17    0.997555
# 18   -0.871407
# 19    0.650762
# 20    0.531458
# 21    0.071708
# 22   -1.510616
# 23   -0.778415
# 24   -1.049553
# 25   -0.743091
# 26   -1.051582
# 27    0.281058
# 28    0.214861
# 29    0.391785
# 30    1.521131
# 31    1.760475
# 32    0.103583
# 33   -0.273416
# 34   -0.837015
# 35    0.432076
# 36   -0.176712
# 37   -0.195172
# 38   -2.143072
# 39   -0.054543
# 40    0.657816
# 41    0.533812
# 42    1.007823
# 43   -0.915644
# 44   -0.580141
# 45   -0.305264
# 46   -1.089974
# 47    1.293340
# 48    0.013272
# 49   -0.764037
# dtype: float64

# %%
plt.plot(s)

# %%
data = randn(200)
df = DataFrame(data)
df
# Out:
#             0
# 0    0.534229
# 1   -0.416105
# 2    0.959330
# 3    0.643746
# 4   -0.025702
# ..        ...
# 195  0.895711
# 196  0.144102
# 197 -0.728577
# 198 -1.432998
# 199 -0.533826
#
# [200 rows x 1 columns]

# %%
plt.plot(df)

# %%
df.plot()

# %%
data = randn(100)
plt.hist(data)
# Out:
# (array([ 5.,  6., 11., 20., 22., 19.,  9.,  5.,  2.,  1.]),
#  array([-2.32422743, -1.81836081, -1.31249418, -0.80662755, -0.30076092,
#          0.2051057 ,  0.71097233,  1.21683896,  1.72270559,  2.22857222,
#          2.73443884]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, color='indianred')
# Out:
# (array([ 5.,  6., 11., 20., 22., 19.,  9.,  5.,  2.,  1.]),
#  array([-2.32422743, -1.81836081, -1.31249418, -0.80662755, -0.30076092,
#          0.2051057 ,  0.71097233,  1.21683896,  1.72270559,  2.22857222,
#          2.73443884]),
#  <a list of 10 Patch objects>)

# %%
dataset1 = randn(100) 
dataset2 = randn(100)

# %%
plt.hist(dataset1, color='indianred',alpha=0.8,bins=20)
plt.hist(dataset2, alpha=0.4, bins=20)
# Out:
# (array([ 1.,  0.,  1.,  3.,  4.,  2.,  8.,  8., 15.,  7., 16.,  8.,  9.,
#          9.,  4.,  1.,  1.,  1.,  1.,  1.]),
#  array([-2.81228825, -2.51279753, -2.21330681, -1.91381608, -1.61432536,
#         -1.31483464, -1.01534392, -0.7158532 , -0.41636248, -0.11687176,
#          0.18261896,  0.48210968,  0.7816004 ,  1.08109112,  1.38058184,
#          1.68007256,  1.97956328,  2.279054  ,  2.57854473,  2.87803545,
#          3.17752617]),
#  <a list of 20 Patch objects>)

# %%
# Figures and Subplots
fig = plt.figure()

# %%
fig = plt.figure( figsize= (2,4), dpi=100)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) # add_subplot(nrows, ncols, index
ax2 = fig.add_subplot(2,2,2) 
ax3 = fig.add_subplot(2,2,3) 
ax4 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) # add_subplot(nrows, ncols, index
ax2 = fig.add_subplot(2,2,2) 
ax3 = fig.add_subplot(2,2,3) 
ax4 = fig.add_subplot(2,2,4) 
plt.plot(randint(100, size=20))

# %%
s = Series(randint(100, size=20))
s
# Out:
# 0     32
# 1     64
# 2     52
# 3     78
# 4     64
# 5     45
# 6     81
# 7     13
# 8     71
# 9     84
# 10    93
# 11    78
# 12     6
# 13    86
# 14    41
# 15    59
# 16    55
# 17    21
# 18     2
# 19     6
# dtype: int32

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) # add_subplot(nrows, ncols, index)
plt.plot(randn(20))
ax2 = fig.add_subplot(2,2,2) 
plt.plot(randn(20))
ax3 = fig.add_subplot(2,2,3)
plt.plot(randn(20))
ax4 = fig.add_subplot(2,2,4) 
plt.plot(randint(100, size=20))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) # add_subplot(nrows, ncols, index)
plt.plot(randn(20))
ax2 = fig.add_subplot(2,2,2) 
plt.plot(randn(20))
ax3 = fig.add_subplot(2,2,3)
plt.plot(randn(20))
ax4 = fig.add_subplot(2,2,4) 
plt.plot(randint(100, size=20), 'k--')

# %%
fig = plt.figure() 
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(randn(100), 'k-')
ax2.plot(randn(100), 'k--')

# %%
fig = plt.figure() 
fig = plt.figure() 
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.hist(randn(100), bins=20, color='k', alpha=0.25) 
ax2.scatter(np.arange(30), randn(30).cumsum())
fig

# %%
# colors, Markers, and Line Styles
plt.plot(randn(100), 'k--')

# %%
plt.plot(randn(30), 'ko--')

# %%
plt.plot(0.25 * randn(30), color='blue', linestyle='dotted', marker='o')

# %%
data = (0.25 * randn(30))
data
# Out:
# array([ 0.03551295,  0.22724329, -0.09208929, -0.10288548, -0.35496412,
#         0.16789282,  0.51420448, -0.11025221, -0.22728877,  0.52243173,
#        -0.41220053, -0.33925483,  0.76445383,  0.38550497, -0.33580725,
#        -0.01727138, -0.66831605,  0.44288411,  0.17981   , -0.10926845,
#         0.20015293, -0.23898771,  0.03176864,  0.31080262,  0.1929367 ,
#        -0.1098174 ,  0.19805529, -0.51863025,  0.58381   , -0.10512232])

# %%
plt.plot(4 * randn(30), color='gray', linestyle='solid', marker='o')

# %%
plt.plot(randn(30).cumsum())

# %%
plt.plot(randn(30).cumsum(), drawstyle='steps-post')

# %%
#using labels 
data = randn(30).cumsum()
plt.plot(data, 'k--')
plt.plot(data, drawstyle='steps-post')

# %%
plt.plot(data, 'k--', label="Dashed-Line")
plt.plot(data,drawstyle='steps-post', label="steps-post")
plt.legend(loc='best')

# %%
# Plot DataFrame columns
d = {'col1':np.random.randint(100,size=20),
    'col2': np.random.randint(100,size=20)}
d
# Out:
# {'col1': array([89,  6, 73, 76, 61, 25, 31, 15, 53, 56, 63, 24,  4, 43, 49, 26, 24,
#         87, 47, 81]),
#  'col2': array([26, 17, 68, 59, 64, 49, 27, 51, 18, 52, 57,  8, 46, 33,  6, 14, 87,
#          1, 66, 84])}

# %%
df = DataFrame(d)

# %%
df
# Out:
#     col1  col2
# 0     89    26
# 1      6    17
# 2     73    68
# 3     76    59
# 4     61    64
# 5     25    49
# 6     31    27
# 7     15    51
# 8     53    18
# 9     56    52
# 10    63    57
# 11    24     8
# 12     4    46
# 13    43    33
# 14    49     6
# 15    26    14
# 16    24    87
# 17    87     1
# 18    47    66
# 19    81    84

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(df['col1'], 'k', label='col1')
ax.plot(df['col2'],'ko--',label='col2')
ax.legend(loc='upper left')

# %%
df['col1'].plot.bar()

# %%
df['col2'].plot.bar()

# %%
#ticks, Labels, and Legends
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.plot(randn(1000).cumsum())

# %%
data = randn(1000).cumsum()
data
# Out:
# array([ 5.04576528e-03, -1.14636058e+00, -1.93536082e+00, -2.26507661e+00,
#        -2.72558256e+00, -3.59009461e+00, -3.82864120e+00, -5.17435122e+00,
#        -6.45619231e+00, -6.27687753e+00, -5.14158603e+00, -4.06436230e+00,
#        -4.47589885e+00, -4.37537343e+00, -5.56522524e+00, -4.95043922e+00,
#        -4.12212268e+00, -4.21769676e+00, -4.13581678e+00, -5.10547593e+00,
#        -5.49931481e+00, -6.73854419e+00, -4.59924038e+00, -2.79607274e+00,
#        -4.87375505e+00, -4.69292798e+00, -4.51194872e+00, -6.55758306e+00,
#        -5.82648638e+00, -5.38486357e+00, -5.84098098e+00, -5.62836318e+00,
#        -5.47368129e+00, -5.88971514e+00, -7.55088073e+00, -9.54151532e+00,
#        -1.02860767e+01, -8.84398309e+00, -9.81171033e+00, -1.21965043e+01,
#        -1.30561027e+01, -1.22887956e+01, -1.32670593e+01, -1.43060915e+01,
#        -1.38918420e+01, -1.58561341e+01, -1.53262855e+01, -1.33249481e+01,
# ...

# %%
ax.set_xticks([0,250,500,750,1000])
ax.set_xticklabels(['One','Two','Three','Four','Five'],
                    rotation=30,fontsize='small')

ax.set_title("My first Matplotlip Plot With Ticks")
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
fig

# %%
props = {'title': "My first Matplotlip Plot with Ticks",
        'xlabel': "Stages",
        'ylabel': "Values"
        
}
ax.set(**props)
fig

# %%
fig.savefig('fig.png')
