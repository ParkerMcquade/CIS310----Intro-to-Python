# %% [markdown]
# # Parker McQuade
# ## Week 15 & 16 - 04/27/2023 through 05/02/2023
# ### Python Data Cleaning and Visualization Project - Python Stock Market Project For Amazon

# %%
# The normal imports
import numpy as np 
from numpy.random import randn, randint
import pandas as pd
from pandas import Series, DataFrame

# Plotting modules and libraries we will use 
import matplotlib as mpl
import matplotlib.pyplot as plt

#Command so that plots appeat in the iPython Notebook
# %matplotlib inline

# %%
#Upload dataset from a csv file
data = pd.read_csv('AMZN.csv')

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
# data info 
data.head(10)
# Out:
#         Date Source        Open        High         Low       Close  \
# 0   1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1   1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2   1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3   1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4   1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
# 5  1/10/2012  yahoo  181.100006  182.399994  177.100006  179.339996
# 6  1/11/2012  yahoo  179.639999  180.770004  178.190002  178.899994
# 7  1/12/2012  yahoo  179.419998  179.490005  175.750000  175.929993
# 8  1/13/2012  yahoo  175.809998  178.800003  173.500000  178.419998
# 9  1/17/2012  yahoo  180.149994  183.300003  178.509995  181.660004
#
#     Adj Close   Volume   Stock
# 0  179.029999  5110800  amazon
# 1  177.509995  4205200  amazon
# 2  177.610001  3809100  amazon
# 3  182.610001  7008400  amazon
# 4  178.559998  5056900  amazon
# ...

# %%
data.tail(10)
# Out:
#             Date Source         Open         High          Low        Close  \
# 2232  11/13/2020  yahoo  3122.000000  3141.719971  3085.389893  3128.810059
# 2233  11/16/2020  yahoo  3093.199951  3142.699951  3072.689941  3131.060059
# 2234  11/17/2020  yahoo  3183.540039  3189.250000  3135.260010  3135.659912
# 2235  11/18/2020  yahoo  3134.000000  3140.000000  3105.100098  3105.459961
# 2236  11/19/2020  yahoo  3105.310059  3125.000000  3080.919922  3117.020020
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# 2232  3128.810059  3756200  amazon
# 2233  3131.060059  3808700  amazon
# ...

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2241.000000  2240.000000  2242.000000  2239.000000  2241.000000
# mean    991.401419  1002.190218   979.221717   991.895355   991.190696
# std     802.269032   811.968123   790.843600   801.664757   801.654109
# min     173.809998   178.250000   172.000000   175.929993   175.929993
# 25%     320.359985   323.687500   315.807487   321.385010   320.510010
# 50%     717.380005   723.394989   712.629975   719.299988   719.070007
# 75%    1660.000000  1679.964966  1633.707459  1661.830017  1660.510010
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.242000e+03
# mean   4.118187e+06
# std    2.278888e+06
# min    0.000000e+00
# 25%    2.688550e+06
# 50%    3.528700e+06
# 75%    4.839800e+06
# max    2.385610e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2242 non-null   object
#  1   Source     2242 non-null   object
#  2   Open       2241 non-null   float64
#  3   High       2240 non-null   float64
#  4   Low        2242 non-null   float64
#  5   Close      2239 non-null   float64
#  6   Adj Close  2241 non-null   float64
#  7   Volume     2242 non-null   int64
#  8   Stock      2242 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 157.8+ KB

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
data['Adj Close'].plot(legend=True, figsize=(10,4))

# %%
data.columns
# Out:
# Index(['Date', 'Source', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Stock'],
#       dtype='object')

# %%
#count the number of numerical and non-numerical variables (columns) 
from pandas.api.types import is_numeric_dtype

n=0
for c in data.columns: 
    if is_numeric_dtype(data[c]):
        n += 1
        
print('Numerical Columns: ', n, 'Non-Numerical Columns: ', len(data.columns) - n)
# Out:
# Numerical Columns:  6 Non-Numerical Columns:  3

# %%
# Data cleaning - Preparing data for analytics
data.isnull()
# Out:
#        Date  Source   Open   High    Low  Close  Adj Close  Volume  Stock
# 0     False   False  False  False  False  False      False   False  False
# 1     False   False  False  False  False  False      False   False  False
# 2     False   False  False  False  False  False      False   False  False
# 3     False   False  False  False  False  False      False   False  False
# 4     False   False  False  False  False  False      False   False  False
# ...     ...     ...    ...    ...    ...    ...        ...     ...    ...
# 2237  False   False  False  False  False  False      False   False  False
# 2238  False   False  False  False  False  False      False   False  False
# 2239  False   False  False  False  False  False      False   False  False
# 2240  False   False  False  False  False  False      False   False  False
# 2241  False   False  False  False  False  False      False   False  False
#
# [2242 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         1
# High         2
# Low          0
# Close        3
# Adj Close    1
# Volume       0
# Stock        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Stock        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2235 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2235 non-null   object
#  1   Source     2235 non-null   object
#  2   Open       2235 non-null   float64
#  3   High       2235 non-null   float64
#  4   Low        2235 non-null   float64
#  5   Close      2235 non-null   float64
#  6   Adj Close  2235 non-null   float64
#  7   Volume     2235 non-null   int64
#  8   Stock      2235 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 174.6+ KB

# %%
#Clean abnormal values 
data['Volume'].plot(kind='hist',bins=50)

# %%
data['Volume'].plot(kind='hist',bins=100)

# %%
#Min & Max
data['Volume'].min()
# Out:
# 0

# %%
data['Volume'].max()
# Out:
# 23856100

# %%
data['Volume'].sort_values(ascending=True)
# Out:
# 29            0
# 114           1
# 18            5
# 161           6
# 47           23
#          ...
# 707    19801100
# 20     21336600
# 894    21909400
# 80     22116900
# 773    23856100
# Name: Volume, Length: 2235, dtype: int64

# %%
data['Volume'].sort_values(ascending=True).head(20)
# Out:
# 29            0
# 114           1
# 18            5
# 161           6
# 47           23
# 90           25
# 66           78
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# Name: Volume, dtype: int64

# %%
#Remove the volume entries with extermine low values (values < 100,000)
data = data[data['Volume'] >= 100000]

# %%
data.shape
# Out:
# (2228, 9)

# %%
data.head(20)
# Out:
#          Date Source        Open        High         Low       Close  \
# 0    1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1    1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2    1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3    1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4    1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
# 5   1/10/2012  yahoo  181.100006  182.399994  177.100006  179.339996
# 6   1/11/2012  yahoo  179.639999  180.770004  178.190002  178.899994
# 7   1/12/2012  yahoo  179.419998  179.490005  175.750000  175.929993
# 8   1/13/2012  yahoo  175.809998  178.800003  173.500000  178.419998
# 9   1/17/2012  yahoo  180.149994  183.300003  178.509995  181.660004
# 10  1/18/2012  yahoo  181.940002  190.250000  181.119995  189.440002
# 11  1/19/2012  yahoo  190.880005  195.940002  190.360001  194.449997
# 12  1/20/2012  yahoo  190.710007  192.899994  189.039993  190.929993
# ...

# %%
data['Volume'].sort_values(ascending=True).head(20)
# Out:
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# 749     1513800
# 1167    1524100
# 151     1534300
# 417     1534700
# 152     1548100
# 1160    1563300
# 416     1566400
# Name: Volume, dtype: int64

# %%
# Remove all columns that have a constant/single value 
constant_columns = []
for c in data.columns:
    n = len(data[c].unique())
    if n ==1: 
        constant_columns.append(c)
        
print(f'Constant Column Names {constant_columns}')
# Out:
# Constant Column Names ['Source', 'Stock']

# %%
len(data['Source'].unique())
# Out:
# 1

# %%
data['Source'].unique()
# Out:
# array(['yahoo'], dtype=object)

# %%
#drop/remove the constant columns from the data set
data.drop(columns=constant_columns, axis=1,inplace=True)
data
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# ...

# %%
data.shape
# Out:
# (2228, 7)

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume
# 0      179.029999  5110800
# 1      177.509995  4205200
# 2      177.610001  3809100
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 139.2+ KB

# %%
dateObject = pd.DatetimeIndex(data['Date'])

# %%
data['Year'] = dateObject.year
data['Month'] = dateObject.month
data['Day'] = dateObject.day
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data[['Date','Year','Month','Day']]
# Out:
#             Date  Year  Month  Day
# 0       1/3/2012  2012      1    3
# 1       1/4/2012  2012      1    4
# 2       1/5/2012  2012      1    5
# 3       1/6/2012  2012      1    6
# 4       1/9/2012  2012      1    9
# ...          ...   ...    ...  ...
# 2237  11/20/2020  2020     11   20
# 2238  11/23/2020  2020     11   23
# 2239  11/24/2020  2020     11   24
# 2240  11/25/2020  2020     11   25
# 2241  11/27/2020  2020     11   27
#
# [2228 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   int64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 191.5+ KB

# %%
data.shape
# Out:
# (2228, 10)

# %%
# Tranform the values of Volume entries to represent thousands
data['Volume'] = data['Volume'] /1000
data.head(10)
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Date        Open        High         Low       Close   Adj Close  \
# 0   1/3/2012  175.889999  179.479996  175.550003  179.029999  179.029999
# 1   1/4/2012  179.210007  180.500000  176.070007  177.509995  177.509995
# 2   1/5/2012  175.940002  178.250000  174.050003  177.610001  177.610001
# 3   1/6/2012  178.070007  184.649994  177.500000  182.610001  182.610001
# 4   1/9/2012  182.759995  184.369995  177.000000  178.559998  178.559998
# 5  1/10/2012  181.100006  182.399994  177.100006  179.339996  179.339996
# 6  1/11/2012  179.639999  180.770004  178.190002  178.899994  178.899994
# ...

# %%
# Use visualization for data analysis 
dataGroup = data[['Year', 'Volume']].groupby('Year').sum()
dataGroup
# Out:
#          Volume
# Year
# 2012   975492.4
# 2013   747905.7
# 2014  1029066.7
# 2015   957102.0
# 2016  1038756.3
# 2017   882705.4
# 2018  1417897.6
# 2019   974729.4
# 2020  1166035.7

# %%
dataGroup.plot(figsize=(8,6), y= 'Volume',color='orange', fontsize=12,title="Stock Volume Over Years")
plt.ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %%
dataGroup = data[['Month','Volume']].groupby('Month').sum()
dataGroup
# Out:
#          Volume
# Month
# 1      884620.5
# 2      846030.2
# 3      839584.5
# 4      890804.0
# 5      693382.7
# 6      671267.7
# 7      792035.2
# 8      633655.4
# 9      650017.7
# 10     897270.2
# 11     743073.6
# 12     647949.5

# %%
dataGroup.plot(figsize=(8,6), y= 'Volume',color='red', fontsize=12,title="Stock Volume Over Months")
plt.ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %%
dataGroup = data[['Day','Volume']].groupby('Day').mean()
dataGroup
# Out:
#           Volume
# Day
# 1    4499.956061
# 2    4236.591667
# 3    4141.492857
# 4    4172.901449
# 5    3962.898667
# 6    3891.351948
# 7    3891.741096
# 8    3685.433784
# 9    3985.105333
# 10   3812.631579
# 11   3746.886842
# 12   3775.222368
# 13   3849.997468
# 14   3836.887671
# 15   4211.287324
# 16   4004.870423
# 17   3902.925333
# 18   4003.701370
# 19   3888.445946
# 20   3960.612000
# 21   3989.059722
# 22   3482.028169
# 23   3836.312000
# 24   4581.157333
# 25   4536.282090
# 26   4714.436986
# 27   4870.135526
# 28   4563.546479
# 29   4596.323881
# 30   4789.813636
# 31   5031.240000

# %%
dataGroup.plot(figsize=(8,6), y= 'Volume',color='Green', fontsize=12,title="Stock Volume Over Days")
plt.ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %%
dataGroup = data[['Day','Volume']].groupby('Day').sum()

# %%
dataGroup.plot.bar(figsize=(8,6), y= 'Volume',color='purple', fontsize=12,title="Stock Volume Over Days")
plt.ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %%
data[['Date','Adj Close']].groupby('Date').count()
# Out:
#            Adj Close
# Date
# 1/10/2012          1
# 1/10/2013          1
# 1/10/2014          1
# 1/10/2017          1
# 1/10/2018          1
# ...              ...
# 9/9/2014           1
# 9/9/2015           1
# 9/9/2016           1
# 9/9/2019           1
# 9/9/2020           1
#
# [2228 rows x 1 columns]

# %%
data[['Date','Adj Close']].plot(figsize=(10,8), x='Date', y='Adj Close', fontsize=12, title="Closing Price Per Date")
plt.ylabel("Stock Adj close")
# Out:
# Text(0, 0.5, 'Stock Adj close')

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y')
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   datetime64[ns]
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 191.5 KB

# %%
data[['Date','Adj Close']].plot(figsize=(10,8), x='Date',color='Green', y='Adj Close', fontsize=12, title="Closing Price Per Date")
plt.ylabel("Stock Adj close")
# Out:
# Text(0, 0.5, 'Stock Adj close')

# %%
dataGroup = data[['Month','Adj Close']].groupby('Month').sum()
dataGroup
# Out:
#            Adj Close
# Month
# 1      152373.629950
# 2      146053.359938
# 3      166751.649797
# 4      171224.489851
# 5      184985.700313
# 6      193977.700201
# 7      212203.470119
# 8      220699.389863
# 9      204492.010192
# 10     223882.629720
# 11     200683.650231
# 12     141332.179765

# %%
dataGroup.plot(figsize=(10,8), y='Adj Close', fontsize=12, title="Closing Price Over Months")
plt.ylabel("Stock Adj close")
# Out:
# Text(0, 0.5, 'Stock Adj close')

# %%
dataGroup = data[['Year','Adj Close']].groupby('Year').sum().plot(figsize=(10,8), y='Adj Close', fontsize=12, title="Closing Price Over Years")
plt.ylabel("Stock Adj close")
# Out:
# Text(0, 0.5, 'Stock Adj close')

# %%
dataGroup = data[['Day','Adj Close']].groupby('Day').mean().plot(figsize=(10,8), y='Adj Close', fontsize=12, title="Average Closing Price Over Days")
plt.ylabel("Stock Adj close")
# Out:
# Text(0, 0.5, 'Stock Adj close')

# %%
# find the years that Adj Close prices smaller than the Open Prices, after 2015
#Using Filters
data1 = data[data['Year'] > 2015]
data1
# Out:
#            Date         Open         High          Low        Close  \
# 1006 2016-01-04   656.289978   657.719971   627.510010   636.989990
# 1007 2016-01-05   646.859985   646.909973   627.650024   633.789978
# 1008 2016-01-06   622.000000   639.789978   620.309998   632.650024
# 1009 2016-01-07   621.799988   630.000000   605.210022   607.940002
# 1010 2016-01-08   619.659973   624.140015   606.000000   607.049988
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 1006   636.989990  9314.5  2016      1    4
# 1007   633.789978  5822.6  2016      1    5
# ...

# %%
len(data1)
# Out:
# 1236

# %%
data2 = data[ data['Open'] > data['Adj Close']]

# %%
len(data2)
# Out:
# 1105

# %%
data2['Open'].max() - data['Adj Close'].max()
# Out:
# 15.5500490000004

# %%
# Use filter1 and filter2
filter1=data['Year'] > 2015
filter1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2237     True
# 2238     True
# 2239     True
# 2240     True
# 2241     True
# Name: Year, Length: 2228, dtype: bool

# %%
filter2=data['Open'] > data['Adj Close']
filter2
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2237     True
# 2238     True
# 2239    False
# 2240    False
# 2241     True
# Length: 2228, dtype: bool

# %%
result=data[filter1 & filter2]

# %%
result['Open'].sum() - result['Adj Close'].sum()
# Out:
# 11206.19128899998

# %%
result[['Year', 'Adj Close']].groupby('Year').count()
# Out:
#       Adj Close
# Year
# 2016        127
# 2017        128
# 2018        124
# 2019        125
# 2020        112

# %%
result[['Year', 'Adj Close']].groupby('Year').count().plot.bar(figsize=(10,8), y='Adj Close', fontsize=12, legend=True,
                            title= "Number of Closing Price is Smaller than Open Price")
plt.ylabel("Number of Stocks")
# Out:
# Text(0, 0.5, 'Number of Stocks')

# %%
result[['Month', 'Adj Close']].groupby('Month').count().plot.bar(figsize=(10,8), y='Adj Close', fontsize=12, legend=True,
                            title= "Number of Closing Price is Smaller than Open Price")
plt.ylabel("Number of Stocks")
# Out:
# Text(0, 0.5, 'Number of Stocks')

# %%
result[['Month', 'Adj Close']].groupby('Month').count()
# Out:
#        Adj Close
# Month
# 1             50
# 2             48
# 3             48
# 4             53
# 5             43
# 6             47
# 7             50
# 8             61
# 9             52
# 10            64
# 11            53
# 12            47

# %%
#Compare the average High, Low and Adj Close values/prices over months 
r=data[['Month','High','Low','Adj Close']].groupby('Month').mean()
r
# Out:
#               High          Low    Adj Close
# Month
# 1       845.138624   826.699177   837.217747
# 2       869.500417   848.818237   859.137411
# 3       883.179059   860.221100   873.045287
# 4       935.481024   913.718432   925.537783
# 5       981.422476   964.186472   973.608949
# 6      1030.305523  1010.421686  1020.935264
# 7      1117.510261  1090.640261  1105.226407
# 8      1124.288736  1103.972829  1114.643383
# 9      1137.103572  1110.570271  1123.582474
# 10     1134.387446  1105.711601  1119.413149
# 11     1114.245054  1089.462911  1102.657419
# 12      861.799519   842.490300   851.398673

# %%
r.plot(figsize=(10,8),y=['High','Low','Adj Close'], fontsize=12, legend=True, title="Compare the Average of High, Low, Adj Close Stock Prices")
plt.ylabel('Average of Stock Prices')
# Out:
# Text(0, 0.5, 'Average of Stock Prices')

# %%
#Find the Months that have the highest and Lowest number of volume
r = data[['Month', 'Volume']].groupby('Month').sum()
r
# Out:
#          Volume
# Month
# 1      884620.5
# 2      846030.2
# 3      839584.5
# 4      890804.0
# 5      693382.7
# 6      671267.7
# 7      792035.2
# 8      633655.4
# 9      650017.7
# 10     897270.2
# 11     743073.6
# 12     647949.5

# %%
print(r.min(), r.max())
# Out:
# Volume    633655.4
# dtype: float64 Volume    897270.2
# dtype: float64

# %%
print(r.min(),"\n", r.max())
# Out:
# Volume    633655.4
# dtype: float64
#  Volume    897270.2
# dtype: float64

# %%
print(r.idxmin(),"\n", r.idxmax())
# Out:
# Volume    8
# dtype: int64
#  Volume    10
# dtype: int64

# %%
print(f'The months that has the lowest volume, {r.idxmin()[0]}, with Volume, {r.min()[0]}')
# Out:
# The months that has the lowest volume, 8, with Volume, 633655.3999999996

# %%
print(f'The months that has the highest volume, {r.idxmax()[0]}, with Volume, {r.max()[0]}')
# Out:
# The months that has the highest volume, 10, with Volume, 897270.1999999995

# %%
#Find the Dates that have the highest and lowest number of volumes
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
r = data['Volume']
r
# Out:
# 0       5110.8
# 1       4205.2
# 2       3809.1
# 3       7008.4
# 4       5056.9
#          ...
# 2237    3374.4
# 2238    4708.9
# 2239    3602.1
# 2240    3790.4
# 2241    2392.9
# Name: Volume, Length: 2228, dtype: float64

# %%
s=r.idxmin()
l = r.idxmax()
print(f'The row index with the lowest volume is, {s}')
print(f'The row index with the highest volume is, {l}')
# Out:
# The row index with the lowest volume is, 2007
# The row index with the highest volume is, 773

# %%
print(f"The date for the lowest volume,{data.iloc[s]}['Date'].date(), Volume {data.iloc[s]['Volume']}")
# Out:
# The date for the lowest volume,Date         2020-01-15 00:00:00
# Open                     1872.25
# High                     1878.86
# Low                      1855.09
# Close                    1862.02
# Adj Close                1862.02
# Volume                    2896.6
# Year                        2020
# Month                          1
# Day                           15
# Name: 2021, dtype: object['Date'].date(), Volume 2896.6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   datetime64[ns]
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 191.5 KB

# %%
print(f"The date for the highest volume, {data.iloc[l]['Date'].date()}, Volume {data.iloc[l]['Volume']}")
# Out:
# The date for the highest volume, 2015-02-20, Volume 3258.0

# %%
# find the month and day that have the lowest closing price!
g=data[['Month','Day','Adj Close']].groupby(['Month','Day']).mean()
g.head(50)
# Out:
#              Adj Close
# Month Day
# 1     2     931.658335
#       3     881.009992
#       4     769.301659
#       5     624.636002
#       6     700.508339
#       7     851.536667
#       8     910.175703
#       9     844.117504
#       10    918.849997
#       11    796.806687
#       12    640.813996
#       13    692.398344
#       14    840.531652
#       15    843.580012
#       16    970.341654
#       17    930.629988
#       18    851.711975
#       19    718.137478
#       20    465.117508
#       21    792.830002
#       22    918.338584
#       23    858.935001
#       24   1059.596680
#       25    825.559990
#       26    669.086017
#       27    689.309993
#       28    850.144999
#       29    916.127154
#       30    977.087154
#       31    974.349993
# 2     1     811.308327
#       2     673.637988
#       3     811.033990
#       4     865.320002
#       5     939.720014
#       6     889.399996
#       7     961.204293
#       8     782.326668
# ...

# %%
g.tail(50)
# Out:
#              Adj Close
# Month Day
# 11    11   1164.614990
#       12   1154.034284
#       13   1147.988766
#       14    875.384280
#       15    969.771647
#       16   1246.881686
#       17   1197.657983
#       18   1162.133321
#       19   1137.794305
#       20   1132.754997
#       21    872.929993
#       22   1014.880005
#       23   1259.887988
#       24   1327.712524
#       25   1187.716680
#       26    867.365979
#       27   1299.210013
#       28    844.774002
#       29   1007.175006
#       30    906.868008
# 12    1     727.765000
#       2     783.312000
#       3     860.009992
#       4     884.437131
#       5     765.414985
#       6    1001.363312
#       7     896.488010
#       8     728.325012
#       9     776.069995
#       10    830.658333
#       11    877.324288
#       12    898.485707
#       13    998.879995
#       14    888.418005
#       15    726.212509
#       16    777.356000
#       17    820.435015
#       18    877.759997
# ...

# %%
g.idxmin()
# Out:
# Adj Close    (2, 29)
# dtype: object

# %%
g.idxmax()
# Out:
# Adj Close    (9, 1)
# dtype: object

# %%
print(f"The month and day with the lowest price is, {g.idxmin()[0]}, the average Adj Close price is {g.min()[0]}")
# Out:
# The month and day with the lowest price is, (2, 29), the average Adj Close price is 366.105011

# %%
print(f"The month and day with the highest price is, {g.idxmax()[0]}, the average Adj Close price is {g.max()[0]}")
# Out:
# The month and day with the highest price is, (9, 1), the average Adj Close price is 1436.1325302500002
